# %% [markdown]
# # Task 2

# %%
#Loading libraries
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, SpatialDropout2D, BatchNormalization, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D, Conv1D
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from keras.utils.np_utils import to_categorical
from keras.optimizers import Adagrad, SGD, RMSprop

# %%
# Loading the data set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Train split to validation
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size = 0.2)
# Normalizing the data
x_train = x_train.astype('float32') / 255 
x_valid = x_valid.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# One - Hot - Key Coding
N = 10
y_train = to_categorical(y_train, N)
y_valid = to_categorical(y_valid, N)
y_test = to_categorical(y_test, N)

# %%
# Defining Nureal Network Model
def Model():
    model = Sequential()  
    model.add(Conv2D(64, kernel_size=(5,5), strides = 1, padding='same', input_shape=(32, 32, 3)))
    model.add(SpatialDropout2D(rate=0.2))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))
    

    model.add(Conv2D(192, kernel_size=(5,5), strides = 1, padding='same'))
    model.add(SpatialDropout2D(rate=0.2))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))

    model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same'))
    model.add(SpatialDropout2D(rate=0.2))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))

    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same'))
    model.add(SpatialDropout2D(rate=0.2))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))
    model.add(Activation('relu'))
        
    model.add(Conv2D(256, kernel_size=(5,5), strides = 1, padding='same'))
    model.add(SpatialDropout2D(rate=0.2))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))

    model.add(Flatten())
    
    model.add(Dense(4096))
    model.add(Activation('relu'))
    model.add(Dropout(rate=0.5))
              
    model.add(Dense(4096))
    model.add(Activation('relu'))
    model.add(Dropout(rate=0.5))         
    
    model.add(Dense(10))
    model.add(Activation('softmax'))
    return model

# %%
# Training of Model
optimizers = ['sgd', 'adagrad',  'rmsprop']
batch_dic = {}
score_dic = {}

# Model Instances 
sgd     = SGD(learning_rate=0.01, momentum=0.0, nesterov=False, name="SGD")
adagrad = Adagrad(learning_rate=0.01)
rmsprop = RMSprop(learning_rate=0.01)
model = []
for i in range(len(optimizers)):
  model.append(Model())
  model[i].compile(loss='categorical_crossentropy', optimizer = optimizers[i], metrics=['accuracy'])

# %%
for idx, val in enumerate(optimizers):
  batch_dic[val] = model[idx].fit(x_train, y_train, batch_size = 32, epochs=60, validation_data=(x_valid, y_valid))
  score_dic[val] = model[idx].evaluate(x_test, y_test, verbose=0)
# Out:
# Epoch 1/60
# 1250/1250 [==============================] - 12s 8ms/step - loss: 2.3029 - accuracy: 0.0966 - val_loss: 2.3014 - val_accuracy: 0.1524
# Epoch 2/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.3012 - accuracy: 0.1103 - val_loss: 2.2892 - val_accuracy: 0.1145
# Epoch 3/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.2598 - accuracy: 0.1335 - val_loss: 2.1015 - val_accuracy: 0.2105
# Epoch 4/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.1056 - accuracy: 0.2101 - val_loss: 1.9813 - val_accuracy: 0.2586
# Epoch 5/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.9992 - accuracy: 0.2399 - val_loss: 1.8456 - val_accuracy: 0.2875
# Epoch 6/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.8594 - accuracy: 0.2872 - val_loss: 1.7168 - val_accuracy: 0.3397
# Epoch 7/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7421 - accuracy: 0.3362 - val_loss: 1.6415 - val_accuracy: 0.3821
# Epoch 8/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6448 - accuracy: 0.3799 - val_loss: 1.5273 - val_accuracy: 0.4323
# Epoch 9/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5652 - accuracy: 0.4211 - val_loss: 1.4228 - val_accuracy: 0.4735
# Epoch 10/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4787 - accuracy: 0.4465 - val_loss: 1.3551 - val_accuracy: 0.4969
# Epoch 11/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4040 - accuracy: 0.4835 - val_loss: 1.3512 - val_accuracy: 0.4966
# Epoch 12/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3256 - accuracy: 0.5126 - val_loss: 1.2066 - val_accuracy: 0.5612
# Epoch 13/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2708 - accuracy: 0.5339 - val_loss: 1.1670 - val_accuracy: 0.5714
# Epoch 14/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2006 - accuracy: 0.5629 - val_loss: 1.1287 - val_accuracy: 0.5904
# Epoch 15/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1502 - accuracy: 0.5815 - val_loss: 1.0653 - val_accuracy: 0.6125
# Epoch 16/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1027 - accuracy: 0.6029 - val_loss: 1.0566 - val_accuracy: 0.6231
# Epoch 17/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.0507 - accuracy: 0.6230 - val_loss: 0.9729 - val_accuracy: 0.6567
# Epoch 18/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9986 - accuracy: 0.6412 - val_loss: 0.9703 - val_accuracy: 0.6539
# Epoch 19/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9512 - accuracy: 0.6595 - val_loss: 0.9047 - val_accuracy: 0.6841
# Epoch 20/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.9001 - accuracy: 0.6766 - val_loss: 0.8567 - val_accuracy: 0.6980
# Epoch 21/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.8522 - accuracy: 0.7023 - val_loss: 0.8937 - val_accuracy: 0.6904
# Epoch 22/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7950 - accuracy: 0.7200 - val_loss: 0.8226 - val_accuracy: 0.7162
# Epoch 23/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7640 - accuracy: 0.7296 - val_loss: 0.8315 - val_accuracy: 0.7087
# Epoch 24/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.7222 - accuracy: 0.7463 - val_loss: 0.7802 - val_accuracy: 0.7335
# Epoch 25/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6843 - accuracy: 0.7587 - val_loss: 0.7962 - val_accuracy: 0.7265
# Epoch 26/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6434 - accuracy: 0.7750 - val_loss: 0.7993 - val_accuracy: 0.7333
# Epoch 27/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5962 - accuracy: 0.7925 - val_loss: 0.7531 - val_accuracy: 0.7473
# Epoch 28/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5683 - accuracy: 0.7989 - val_loss: 0.7425 - val_accuracy: 0.7520
# Epoch 29/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5342 - accuracy: 0.8140 - val_loss: 0.7411 - val_accuracy: 0.7584
# Epoch 30/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5004 - accuracy: 0.8233 - val_loss: 0.7713 - val_accuracy: 0.7521
# Epoch 31/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4713 - accuracy: 0.8352 - val_loss: 0.7603 - val_accuracy: 0.7595
# Epoch 32/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4389 - accuracy: 0.8460 - val_loss: 0.7982 - val_accuracy: 0.7496
# Epoch 33/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4045 - accuracy: 0.8591 - val_loss: 0.7582 - val_accuracy: 0.7642
# Epoch 34/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3752 - accuracy: 0.8671 - val_loss: 0.7541 - val_accuracy: 0.7689
# Epoch 35/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3464 - accuracy: 0.8790 - val_loss: 0.7864 - val_accuracy: 0.7637
# Epoch 36/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3232 - accuracy: 0.8846 - val_loss: 0.8212 - val_accuracy: 0.7632
# Epoch 37/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.3046 - accuracy: 0.8952 - val_loss: 0.8638 - val_accuracy: 0.7538
# Epoch 38/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2884 - accuracy: 0.9005 - val_loss: 0.8027 - val_accuracy: 0.7703
# Epoch 39/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2529 - accuracy: 0.9120 - val_loss: 0.8528 - val_accuracy: 0.7661
# Epoch 40/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2474 - accuracy: 0.9122 - val_loss: 0.8459 - val_accuracy: 0.7652
# Epoch 41/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2271 - accuracy: 0.9205 - val_loss: 0.8470 - val_accuracy: 0.7680
# Epoch 42/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2185 - accuracy: 0.9247 - val_loss: 0.9207 - val_accuracy: 0.7658
# Epoch 43/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.2027 - accuracy: 0.9277 - val_loss: 0.8831 - val_accuracy: 0.7718
# Epoch 44/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1960 - accuracy: 0.9320 - val_loss: 0.8952 - val_accuracy: 0.7691
# Epoch 45/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1774 - accuracy: 0.9381 - val_loss: 0.9259 - val_accuracy: 0.7691
# Epoch 46/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1746 - accuracy: 0.9383 - val_loss: 0.9623 - val_accuracy: 0.7627
# Epoch 47/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1488 - accuracy: 0.9495 - val_loss: 0.9315 - val_accuracy: 0.7675
# Epoch 48/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1520 - accuracy: 0.9487 - val_loss: 0.9570 - val_accuracy: 0.7715
# Epoch 49/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1365 - accuracy: 0.9535 - val_loss: 0.9829 - val_accuracy: 0.7689
# Epoch 50/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1365 - accuracy: 0.9525 - val_loss: 1.0411 - val_accuracy: 0.7601
# Epoch 51/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1171 - accuracy: 0.9598 - val_loss: 0.9763 - val_accuracy: 0.7718
# Epoch 52/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1226 - accuracy: 0.9586 - val_loss: 0.9897 - val_accuracy: 0.7729
# Epoch 53/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1180 - accuracy: 0.9592 - val_loss: 1.0010 - val_accuracy: 0.7746
# Epoch 54/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1089 - accuracy: 0.9632 - val_loss: 1.0186 - val_accuracy: 0.7682
# Epoch 55/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1091 - accuracy: 0.9633 - val_loss: 1.0112 - val_accuracy: 0.7629
# Epoch 56/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.1068 - accuracy: 0.9640 - val_loss: 1.0512 - val_accuracy: 0.7730
# Epoch 57/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.0962 - accuracy: 0.9668 - val_loss: 1.1079 - val_accuracy: 0.7592
# Epoch 58/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.0976 - accuracy: 0.9671 - val_loss: 1.0032 - val_accuracy: 0.7748
# Epoch 59/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.0896 - accuracy: 0.9703 - val_loss: 1.0381 - val_accuracy: 0.7767
# Epoch 60/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.0855 - accuracy: 0.9711 - val_loss: 1.0540 - val_accuracy: 0.7780
# Epoch 1/60
# 1250/1250 [==============================] - 14s 9ms/step - loss: 2.3025 - accuracy: 0.1003 - val_loss: 2.3020 - val_accuracy: 0.1190
# Epoch 2/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.3018 - accuracy: 0.1045 - val_loss: 2.3012 - val_accuracy: 0.1277
# Epoch 3/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.3013 - accuracy: 0.1021 - val_loss: 2.2993 - val_accuracy: 0.1149
# Epoch 4/60
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.2989 - accuracy: 0.1046 - val_loss: 2.2934 - val_accuracy: 0.1010
# Epoch 5/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.2917 - accuracy: 0.1015 - val_loss: 2.2649 - val_accuracy: 0.1259
# Epoch 6/60
# 1250/1250 [==============================] - 11s 8ms/step - loss: 2.2481 - accuracy: 0.1389 - val_loss: 2.1709 - val_accuracy: 0.1803
# Epoch 7/60
# 1250/1250 [==============================] - 11s 8ms/step - loss: 2.1785 - accuracy: 0.1787 - val_loss: 2.1371 - val_accuracy: 0.1959
# Epoch 8/60
# 1250/1250 [==============================] - 11s 8ms/step - loss: 2.1494 - accuracy: 0.1888 - val_loss: 2.1040 - val_accuracy: 0.1988
# Epoch 9/60
# 1250/1250 [==============================] - 11s 8ms/step - loss: 2.1175 - accuracy: 0.1950 - val_loss: 2.0754 - val_accuracy: 0.2084
# Epoch 10/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.0842 - accuracy: 0.2018 - val_loss: 2.0318 - val_accuracy: 0.2092
# Epoch 11/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.0560 - accuracy: 0.2166 - val_loss: 1.9810 - val_accuracy: 0.2360
# Epoch 12/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 2.0085 - accuracy: 0.2209 - val_loss: 1.9289 - val_accuracy: 0.2460
# Epoch 13/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.9614 - accuracy: 0.2330 - val_loss: 1.8865 - val_accuracy: 0.2548
# Epoch 14/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.9238 - accuracy: 0.2473 - val_loss: 1.8608 - val_accuracy: 0.2665
# Epoch 15/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.8949 - accuracy: 0.2554 - val_loss: 1.8312 - val_accuracy: 0.2825
# Epoch 16/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.8771 - accuracy: 0.2660 - val_loss: 1.8066 - val_accuracy: 0.2941
# Epoch 17/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.8487 - accuracy: 0.2849 - val_loss: 1.7721 - val_accuracy: 0.3154
# Epoch 18/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.8098 - accuracy: 0.3019 - val_loss: 1.7504 - val_accuracy: 0.3350
# Epoch 19/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7874 - accuracy: 0.3182 - val_loss: 1.7228 - val_accuracy: 0.3476
# Epoch 20/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7685 - accuracy: 0.3239 - val_loss: 1.7118 - val_accuracy: 0.3534
# Epoch 21/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7419 - accuracy: 0.3397 - val_loss: 1.6813 - val_accuracy: 0.3623
# Epoch 22/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7314 - accuracy: 0.3445 - val_loss: 1.6587 - val_accuracy: 0.3724
# Epoch 23/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.7016 - accuracy: 0.3544 - val_loss: 1.6371 - val_accuracy: 0.3810
# Epoch 24/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6818 - accuracy: 0.3698 - val_loss: 1.6163 - val_accuracy: 0.3901
# Epoch 25/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6646 - accuracy: 0.3747 - val_loss: 1.5970 - val_accuracy: 0.3985
# Epoch 26/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6385 - accuracy: 0.3839 - val_loss: 1.5635 - val_accuracy: 0.4142
# Epoch 27/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.6158 - accuracy: 0.3917 - val_loss: 1.5435 - val_accuracy: 0.4191
# Epoch 28/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5871 - accuracy: 0.4056 - val_loss: 1.5219 - val_accuracy: 0.4288
# Epoch 29/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5714 - accuracy: 0.4056 - val_loss: 1.5018 - val_accuracy: 0.4381
# Epoch 30/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5507 - accuracy: 0.4192 - val_loss: 1.4858 - val_accuracy: 0.4431
# Epoch 31/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5311 - accuracy: 0.4298 - val_loss: 1.4632 - val_accuracy: 0.4546
# Epoch 32/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.5073 - accuracy: 0.4384 - val_loss: 1.4569 - val_accuracy: 0.4551
# Epoch 33/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4975 - accuracy: 0.4425 - val_loss: 1.4278 - val_accuracy: 0.4662
# Epoch 34/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4853 - accuracy: 0.4470 - val_loss: 1.4206 - val_accuracy: 0.4673
# Epoch 35/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4593 - accuracy: 0.4595 - val_loss: 1.3945 - val_accuracy: 0.4802
# Epoch 36/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4485 - accuracy: 0.4629 - val_loss: 1.3760 - val_accuracy: 0.4867
# Epoch 37/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4404 - accuracy: 0.4702 - val_loss: 1.3696 - val_accuracy: 0.4906
# Epoch 38/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4155 - accuracy: 0.4771 - val_loss: 1.3448 - val_accuracy: 0.4977
# Epoch 39/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.4152 - accuracy: 0.4727 - val_loss: 1.3346 - val_accuracy: 0.5054
# Epoch 40/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3923 - accuracy: 0.4891 - val_loss: 1.3137 - val_accuracy: 0.5114
# Epoch 41/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3683 - accuracy: 0.4948 - val_loss: 1.3156 - val_accuracy: 0.5148
# Epoch 42/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3607 - accuracy: 0.4932 - val_loss: 1.2987 - val_accuracy: 0.5183
# Epoch 43/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3491 - accuracy: 0.5031 - val_loss: 1.2901 - val_accuracy: 0.5219
# Epoch 44/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3313 - accuracy: 0.5080 - val_loss: 1.2699 - val_accuracy: 0.5293
# Epoch 45/60
# 1250/1250 [==============================] - 11s 8ms/step - loss: 1.3099 - accuracy: 0.5203 - val_loss: 1.2784 - val_accuracy: 0.5250
# Epoch 46/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.3045 - accuracy: 0.5205 - val_loss: 1.2388 - val_accuracy: 0.5402
# Epoch 47/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2983 - accuracy: 0.5236 - val_loss: 1.2322 - val_accuracy: 0.5458
# Epoch 48/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2823 - accuracy: 0.5293 - val_loss: 1.2340 - val_accuracy: 0.5409
# Epoch 49/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2729 - accuracy: 0.5364 - val_loss: 1.2083 - val_accuracy: 0.5559
# Epoch 50/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2602 - accuracy: 0.5364 - val_loss: 1.2002 - val_accuracy: 0.5565
# Epoch 51/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2382 - accuracy: 0.5457 - val_loss: 1.2143 - val_accuracy: 0.5533
# Epoch 52/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2416 - accuracy: 0.5465 - val_loss: 1.1744 - val_accuracy: 0.5662
# Epoch 53/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2251 - accuracy: 0.5526 - val_loss: 1.1635 - val_accuracy: 0.5720
# Epoch 54/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2096 - accuracy: 0.5574 - val_loss: 1.1640 - val_accuracy: 0.5722
# Epoch 55/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.2000 - accuracy: 0.5627 - val_loss: 1.1531 - val_accuracy: 0.5753
# Epoch 56/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1987 - accuracy: 0.5659 - val_loss: 1.1479 - val_accuracy: 0.5776
# Epoch 57/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1882 - accuracy: 0.5692 - val_loss: 1.1321 - val_accuracy: 0.5840
# Epoch 58/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1822 - accuracy: 0.5683 - val_loss: 1.1285 - val_accuracy: 0.5839
# Epoch 59/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1633 - accuracy: 0.5751 - val_loss: 1.1236 - val_accuracy: 0.5868
# Epoch 60/60
# 1250/1250 [==============================] - 10s 8ms/step - loss: 1.1679 - accuracy: 0.5767 - val_loss: 1.1043 - val_accuracy: 0.5942
# Epoch 1/60
# 1250/1250 [==============================] - 16s 11ms/step - loss: 2.3309 - accuracy: 0.1555 - val_loss: 1.6673 - val_accuracy: 0.3908
# Epoch 2/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7334 - accuracy: 0.3720 - val_loss: 1.4659 - val_accuracy: 0.4628
# Epoch 3/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.6420 - accuracy: 0.4142 - val_loss: 1.5042 - val_accuracy: 0.4667
# Epoch 4/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.6489 - accuracy: 0.4258 - val_loss: 1.5663 - val_accuracy: 0.4394
# Epoch 5/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.6695 - accuracy: 0.4299 - val_loss: 1.4044 - val_accuracy: 0.5052
# Epoch 6/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.6725 - accuracy: 0.4221 - val_loss: 1.5736 - val_accuracy: 0.4646
# Epoch 7/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7194 - accuracy: 0.4088 - val_loss: 1.5599 - val_accuracy: 0.4918
# Epoch 8/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7257 - accuracy: 0.4136 - val_loss: 1.6709 - val_accuracy: 0.4159
# Epoch 9/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7172 - accuracy: 0.4088 - val_loss: 1.5701 - val_accuracy: 0.4725
# Epoch 10/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7415 - accuracy: 0.4049 - val_loss: 1.5007 - val_accuracy: 0.4856
# Epoch 11/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7642 - accuracy: 0.4009 - val_loss: 1.5875 - val_accuracy: 0.4405
# Epoch 12/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7259 - accuracy: 0.3969 - val_loss: 1.6012 - val_accuracy: 0.4280
# Epoch 13/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7978 - accuracy: 0.3898 - val_loss: 1.5109 - val_accuracy: 0.4941
# Epoch 14/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8324 - accuracy: 0.3709 - val_loss: 1.5869 - val_accuracy: 0.4576
# Epoch 15/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7862 - accuracy: 0.3830 - val_loss: 1.5336 - val_accuracy: 0.4796
# Epoch 16/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7994 - accuracy: 0.3911 - val_loss: 1.5968 - val_accuracy: 0.4400
# Epoch 17/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8083 - accuracy: 0.3805 - val_loss: 1.5836 - val_accuracy: 0.4518
# Epoch 18/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.7970 - accuracy: 0.3869 - val_loss: 1.8118 - val_accuracy: 0.3483
# Epoch 19/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8320 - accuracy: 0.3667 - val_loss: 1.6311 - val_accuracy: 0.4338
# Epoch 20/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8441 - accuracy: 0.3710 - val_loss: 1.6816 - val_accuracy: 0.3919
# Epoch 21/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8661 - accuracy: 0.3619 - val_loss: 1.5242 - val_accuracy: 0.4501
# Epoch 22/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8205 - accuracy: 0.3676 - val_loss: 1.6692 - val_accuracy: 0.3787
# Epoch 23/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8681 - accuracy: 0.3619 - val_loss: 1.6525 - val_accuracy: 0.4044
# Epoch 24/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.9226 - accuracy: 0.3558 - val_loss: 1.5696 - val_accuracy: 0.4446
# Epoch 25/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8477 - accuracy: 0.3612 - val_loss: 1.5897 - val_accuracy: 0.4577
# Epoch 26/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8896 - accuracy: 0.3581 - val_loss: 1.6489 - val_accuracy: 0.4187
# Epoch 27/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8328 - accuracy: 0.3582 - val_loss: 1.6152 - val_accuracy: 0.3933
# Epoch 28/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8562 - accuracy: 0.3608 - val_loss: 1.5888 - val_accuracy: 0.4487
# Epoch 29/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8799 - accuracy: 0.3555 - val_loss: 1.6373 - val_accuracy: 0.3977
# Epoch 30/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8309 - accuracy: 0.3544 - val_loss: 1.5899 - val_accuracy: 0.4302
# Epoch 31/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8377 - accuracy: 0.3584 - val_loss: 1.6018 - val_accuracy: 0.4329
# Epoch 32/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8622 - accuracy: 0.3556 - val_loss: 1.7358 - val_accuracy: 0.3757
# Epoch 33/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8672 - accuracy: 0.3534 - val_loss: 1.6691 - val_accuracy: 0.4060
# Epoch 34/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8931 - accuracy: 0.3523 - val_loss: 1.6637 - val_accuracy: 0.3948
# Epoch 35/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8503 - accuracy: 0.3513 - val_loss: 1.6493 - val_accuracy: 0.4240
# Epoch 36/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8672 - accuracy: 0.3483 - val_loss: 1.6169 - val_accuracy: 0.4391
# Epoch 37/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8639 - accuracy: 0.3547 - val_loss: 1.5928 - val_accuracy: 0.4206
# Epoch 38/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 2.1226 - accuracy: 0.3487 - val_loss: 1.7208 - val_accuracy: 0.3860
# Epoch 39/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8160 - accuracy: 0.3619 - val_loss: 1.5065 - val_accuracy: 0.4644
# Epoch 40/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8245 - accuracy: 0.3574 - val_loss: 1.5599 - val_accuracy: 0.4421
# Epoch 41/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.9727 - accuracy: 0.3498 - val_loss: 1.6121 - val_accuracy: 0.4077
# Epoch 42/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8314 - accuracy: 0.3569 - val_loss: 1.6178 - val_accuracy: 0.4049
# Epoch 43/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 2.1609 - accuracy: 0.3453 - val_loss: 1.6060 - val_accuracy: 0.4326
# Epoch 44/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8314 - accuracy: 0.3649 - val_loss: 1.6923 - val_accuracy: 0.3822
# Epoch 45/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8732 - accuracy: 0.3470 - val_loss: 1.7327 - val_accuracy: 0.3776
# Epoch 46/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8651 - accuracy: 0.3421 - val_loss: 1.5977 - val_accuracy: 0.4186
# Epoch 47/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8324 - accuracy: 0.3457 - val_loss: 1.6625 - val_accuracy: 0.4078
# Epoch 48/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8517 - accuracy: 0.3484 - val_loss: 1.7329 - val_accuracy: 0.3631
# Epoch 49/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8345 - accuracy: 0.3455 - val_loss: 1.6595 - val_accuracy: 0.3918
# Epoch 50/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8750 - accuracy: 0.3426 - val_loss: 1.7161 - val_accuracy: 0.3673
# Epoch 51/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.9115 - accuracy: 0.3299 - val_loss: 1.7154 - val_accuracy: 0.3561
# Epoch 52/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8861 - accuracy: 0.3326 - val_loss: 1.6559 - val_accuracy: 0.3986
# Epoch 53/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8789 - accuracy: 0.3248 - val_loss: 1.7167 - val_accuracy: 0.3730
# Epoch 54/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.9342 - accuracy: 0.3129 - val_loss: 1.6514 - val_accuracy: 0.4055
# Epoch 55/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8904 - accuracy: 0.3188 - val_loss: 1.7181 - val_accuracy: 0.3888
# Epoch 56/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8818 - accuracy: 0.3294 - val_loss: 1.6223 - val_accuracy: 0.3982
# Epoch 57/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8708 - accuracy: 0.3304 - val_loss: 1.6999 - val_accuracy: 0.3748
# Epoch 58/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8649 - accuracy: 0.3374 - val_loss: 1.6762 - val_accuracy: 0.4057
# Epoch 59/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8886 - accuracy: 0.3219 - val_loss: 1.9189 - val_accuracy: 0.2758
# Epoch 60/60
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.8746 - accuracy: 0.3220 - val_loss: 1.6932 - val_accuracy: 0.3605

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-2.0.0-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 16.8 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-2.0.0

# %%
modelName = 'Dropout'

# plottin the graphs and saving
plt.figure(1)
plt.figure(figsize = (18, 12))
for idx, val in enumerate(batch_dic):
  plt.plot(batch_dic[val].history['accuracy'], marker = 'x', label='Training accuracy, optimizer = {batch}'.format(batch = val))
for idx, val in enumerate(batch_dic):  
  plt.plot(batch_dic[val].history['val_accuracy'], marker = "d", alpha = 0.3, label='Validation accuracy, optimizer = {batch}'.format(batch = val))
for idx, val in enumerate(batch_dic):
  plt.plot(np.ones((75,1)) * score_dic[val][1], linewidth = 2, label = 'Test accuracy, optimizer = {batch}'.format(batch = val))

plt.title('{modelName}(Accuracy)'.format(modelName = modelName), fontsize = 16)
plt.grid()
plt.xlabel('Epoch', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(loc='best')
plt.savefig('{modelName}(Accuracy).png'.format(modelName = modelName), dpi=fig.dpi)
plt.show()


plt.figure(2)
plt.figure(figsize = (18, 12))
for idx, val in enumerate(batch_dic):
  plt.plot(batch_dic[val].history['loss'], marker='x', label='training loss, optimizer = {batch}'.format(batch = val))

for idx, val in enumerate(batch_dic):
  plt.plot(batch_dic[val].history['val_loss'], marker='d', alpha = 0.3, label='validation loss, optimizer = {batch}'.format(batch = val))

for idx, val in enumerate(batch_dic):
  plt.plot(np.ones((75,1)) * score_dic[val][1], linewidth = 2, label = 'test loss, optimizer = {batch}'.format(batch = val))



plt.title('{modelName}(Loss)'.format(modelName = modelName), fontsize = 16)
plt.grid()
plt.xlabel('Epoch', fontsize = 14)
plt.ylabel('Loss', fontsize = 14)
plt.legend(loc='best')
plt.savefig('{modelName}(Loss).png'.format(modelName = modelName), dpi=fig.dpi)
plt.show()


#-------------------------------------------Saving records-------------------------------------------
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('{}.xlsx'.format(modelName), engine='xlsxwriter')
df = pd.DataFrame(batch_dic['sgd'].history, columns = ['loss', 'accuracy', 'val_loss' , 'val_accuracy'])
df['Optimizer'] = 'sgd'

temp = pd.DataFrame(batch_dic['adagrad'].history, columns = ['loss', 'accuracy', 'val_loss' , 'val_accuracy'])
temp['Optimizer'] = 'adagrad'
df = df.append(temp)

temp = pd.DataFrame(batch_dic['rmsprop'].history, columns = ['loss', 'accuracy', 'val_loss' , 'val_accuracy'])
temp['Optimizer'] = 'rmsprop'
df = df.append(temp)
df.to_excel(writer, sheet_name = 'Records')

#--------------------------------------------Saving scores----------------------------------------------
df_score = pd.DataFrame(score_dic['sgd'])
df_score = df_score.T
df_score['Optimizer'] = 'sgd'

temp = pd.DataFrame(score_dic['adagrad'])
temp = temp.T
temp['Optimizer'] = 'adagrad'
df_score = df_score.append(temp)

temp = pd.DataFrame(score_dic['rmsprop'])
temp = temp.T
temp['Optimizer'] = 'rmsprop'
df_score = df_score.append(temp)



df_score.rename(columns={0: "Loss", 1: "Accuracy"}, inplace=True)
df_score.to_excel(writer, sheet_name = 'Scores')


# Close the Pandas Excel writer and output the Excel file.
writer.save()
